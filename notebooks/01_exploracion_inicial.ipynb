# %% [markdown]
# # Exploracion inicial\n\nNotebook de apoyo para revisar el dataset UYU/BRL. El analisis reproducible principal esta en `src/`.

# %%
import pandas as pd\ndf = pd.read_csv('../data/raw/dataset_uyu_brl_2005_2026.csv')\ndf.head()
